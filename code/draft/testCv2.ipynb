# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/Bar-Chart-Vertical.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1020x1020 at 0x7FD0AC18BF40>

# %%
rotate_image = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)

cv2_imshow(rotate_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1020x1020 at 0x7FD0AC18BA00>
